# %%
import joblib
import numpy as np
import matplotlib.pyplot as plt

bins = np.linspace(0, 1, 11)

nt = 5
ns = 5
nc = 5
n_arms = ns*nc
ut = (1, 0)
th = 0.5
fr = 0.3

file1 = f'./planning-finite/nt{nt}_ns{ns}_nc{nc}_ut{ut}_th{th}_fr{fr}_Neutral.joblib'
file2 = f'./planning-finite/nt{nt}_ns{ns}_nc{nc}_ut{ut}_th{th}_fr{fr}_RiskAware.joblib'

# Load data from joblib files
data1 = joblib.load(file1)
data2 = joblib.load(file2)

# Extract `totalrewards` from the loaded data
totalrewards1 = data1[0]
totalrewards2 = data2[0]

# %%
# Iterate over each arm and create histograms
for arm in range(n_arms):

    print('='*20)
    print(f"arm = {arm}")
    print(f"percentage above threshold (Neutral) = {100 * sum(totalrewards1[arm, :] >= th)/len(totalrewards1[arm, :])}")
    print(f"percentage above threshold (Risk-Aware) = {100 * sum(totalrewards2[arm, :] >= th)/len(totalrewards2[arm, :])}")

    plt.figure()

    # Histogram for the first file
    plt.hist(
        totalrewards1[arm, :], 
        bins=bins, 
        alpha=0.5, 
        label='Risk Neutral', 
        color='gray', 
        edgecolor='black', 
        linewidth=1.2, 
        hatch='/'  # Adding a hatch pattern for black-and-white distinction
    )

    # Histogram for the second file
    plt.hist(
        totalrewards2[arm, :], 
        bins=bins, 
        alpha=0.5, 
        label='Risk Aware', 
        color='lightgray', 
        edgecolor='black', 
        linewidth=1.2, 
        hatch='\\'  # Adding a different hatch pattern for black-and-white distinction
    )

    plt.axvline(x=th, color='red', linestyle='--', linewidth=1.5, label='Threshold')
    
    # Plot formatting
    plt.title(f'Distribution of Rewards - Arm {arm+1}', fontsize=14, fontweight='bold')
    plt.xlabel('Total Rewards', fontsize=14, fontweight='bold')
    plt.ylabel('Frequency', fontsize=14, fontweight='bold')
    plt.xticks(fontsize=14, fontweight='bold')
    plt.yticks(fontsize=14, fontweight='bold')
    plt.legend(loc='upper left', fontsize=14)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()

    # Show the plot
    plt.show()
# Out:
# ====================
# arm = 0
# percentage above threshold (Neutral) = 58.0
# percentage above threshold (Risk-Aware) = 100.0
# ====================
# arm = 1
# percentage above threshold (Neutral) = 4.0
# percentage above threshold (Risk-Aware) = 8.0
# ====================
# arm = 2
# percentage above threshold (Neutral) = 10.0
# percentage above threshold (Risk-Aware) = 9.0
# ====================
# arm = 3
# percentage above threshold (Neutral) = 11.0
# percentage above threshold (Risk-Aware) = 11.0
# ====================
# arm = 4
# percentage above threshold (Neutral) = 17.0
# percentage above threshold (Risk-Aware) = 18.0
# ====================
# arm = 5
# percentage above threshold (Neutral) = 10.0
# percentage above threshold (Risk-Aware) = 21.0
# ====================
# arm = 6
# percentage above threshold (Neutral) = 10.0
# percentage above threshold (Risk-Aware) = 16.0
# ====================
# arm = 7
# percentage above threshold (Neutral) = 10.0
# percentage above threshold (Risk-Aware) = 18.0
# ====================
# arm = 8
# percentage above threshold (Neutral) = 6.0
# percentage above threshold (Risk-Aware) = 18.0
# ====================
# arm = 9
# percentage above threshold (Neutral) = 6.0
# percentage above threshold (Risk-Aware) = 13.0
# ====================
# arm = 10
# percentage above threshold (Neutral) = 7.0
# percentage above threshold (Risk-Aware) = 19.0
# ====================
# arm = 11
# percentage above threshold (Neutral) = 5.0
# percentage above threshold (Risk-Aware) = 19.0
# ====================
# arm = 12
# percentage above threshold (Neutral) = 5.0
# percentage above threshold (Risk-Aware) = 17.0
# ====================
# arm = 13
# percentage above threshold (Neutral) = 14.0
# percentage above threshold (Risk-Aware) = 12.0
# ====================
# arm = 14
# percentage above threshold (Neutral) = 14.0
# percentage above threshold (Risk-Aware) = 17.0
# ====================
# arm = 15
# percentage above threshold (Neutral) = 10.0
# percentage above threshold (Risk-Aware) = 19.0
# ====================
# arm = 16
# percentage above threshold (Neutral) = 18.0
# percentage above threshold (Risk-Aware) = 16.0
# ====================
# arm = 17
# percentage above threshold (Neutral) = 17.0
# percentage above threshold (Risk-Aware) = 18.0
# ====================
# arm = 18
# percentage above threshold (Neutral) = 17.0
# percentage above threshold (Risk-Aware) = 20.0
# ====================
# arm = 19
# percentage above threshold (Neutral) = 16.0
# percentage above threshold (Risk-Aware) = 19.0
# ====================
# arm = 20
# percentage above threshold (Neutral) = 25.0
# percentage above threshold (Risk-Aware) = 27.0
# ====================
# arm = 21
# percentage above threshold (Neutral) = 26.0
# percentage above threshold (Risk-Aware) = 28.0
# ====================
# arm = 22
# percentage above threshold (Neutral) = 31.0
# percentage above threshold (Risk-Aware) = 28.0
# ====================
# arm = 23
# percentage above threshold (Neutral) = 27.0
# percentage above threshold (Risk-Aware) = 31.0
# ====================
# arm = 24
# percentage above threshold (Neutral) = 43.0
# percentage above threshold (Risk-Aware) = 28.0
